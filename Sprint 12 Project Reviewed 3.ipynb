# %% [markdown]
# <div style="border-radius: 15px; border: 3px solid indigo; padding: 15px;">
# <b> Reviewer's comment 3</b>
#
#
# You almost finished it, great job! My new comments have digit 3. There are just a couple of issues this time. Would you please take a look?
#
# </div>

# %% [markdown]
# <div style="border-radius: 15px; border: 3px solid indigo; padding: 15px;">
# <b> Reviewer's comment 2</b>
#
#
# Thank you for taking the time to update the project, you did a fantastic job here! I've left a couple of new comments with digit 2. Would you please take a look?
#
#
# </div>

# %% [markdown]
# <div style="border-radius: 15px; border: 3px solid indigo; padding: 15px;">
# <b> Reviewer's comment</b>
#
# Hi Byron, I am a reviewer on this project. Congratulations on submitting the numerical methods project! 🎉
#
#
# I will be using the standard color marking:
#
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Reviewer's comment ✔️</b>
#
# Great solutions and ideas that can and should be used in the future are in green comments.
# </div>
#
#
# <div class="alert alert-warning" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Reviewer's comment ⚠️</b>
#
# Yellow color indicates what should be optimized. This is not necessary, but it will be great if you make changes to this project.
# </div>
#
#
# <div class="alert alert-danger" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Reviewer's comment ❌</b>
#
# Issues that need to be corrected to get right results are indicated in red comments. Note that the project cannot be accepted until these issues are resolved.
# </div>
#
# <hr>
#
# **Please, use some color other than those listed to highlight answers to my comments.**
# I would also ask you **not to change, move or delete my comments** so that it would be easier for me to navigate during the next review.
#
# In addition, my comments are defined as headings.
# They can mess up the content; however, they are convenient, since you can immediately go to them.
#
#
#
# <hr>
#
# <font color='dodgerblue'>**A few words about the project:**</font> excellent job on this project, thank you so much!
#
#
# - You have successfully explored the dataframe and conducted preprocessing;
#
#
# - The project also has the EDA part, well done!
#
#
# - You have trained and compared several models and their training speed, great!
#
#
# There are just several issues that need your attention. Would you take a look at my comments?
#
#
# <hr>
#
# 📌 Please feel free to schedule a 1:1 with our tutors or TAs, join daily coworking sessions, or ask questions in the sprint channels on Discord if you need assistance.
# </div>

# %% [markdown]
# #### Sprint 12 Project:
# Numerical Methods

# %% [markdown]
# #### Summary:
#     In this this project, I will be using several machine learning models in order to predict the market value of a car for
# the Rusty Bargain company.  The models included in this project are: Linear Regression, Stochastic Gradient Descent Linear
# Regression, Decision Tree Regressor, Random Forest Regressor, XG Boost, CatBoost Regressor and Light GBM Regressor.  I will
# be using the RMSE metric for evaluating the quality of these model predictions. I will also evaluate the speed of each model's training time and prediction time as well.  There is also a section in this project where I have created a KDE plot and several
# boxplots for descriptive statistics.

# %% [markdown]
# #### Project Description
# Rusty Bargain used car sales service is developing an app to attract new customers. In that app, you can quickly find out the market value of your car. You have access to historical data: technical specifications, trim versions, and prices. You need to build the model to determine the value.
#
# Rusty Bargain is interested in:
#
# - the quality of the prediction;
# - the speed of the prediction;
# - the time required for training

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <h2>   Reviewer's comment </h2>
#
# Good introduction!
#
# </div>
# <div class="alert alert-warning" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <h2>   Reviewer's comment </h2>
#
# Please don't forget about project title :) A title should reflect the core goals.
#
# </div>
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <h2>   Reviewer's comment 2</h2>
#
# Good!
#
# </div>

# %%
#Import the necessary libraries.
import pandas as pd 

from sklearn.tree import DecisionTreeRegressor 

from sklearn.model_selection import train_test_split, GridSearchCV

import numpy as np 

from sklearn.metrics import mean_squared_error, make_scorer

from catboost import CatBoostRegressor 

from lightgbm import LGBMRegressor

from xgboost import XGBRegressor 

from sklearn.ensemble import RandomForestRegressor 

import time 

from sklearn.preprocessing import StandardScaler, OneHotEncoder

from sklearn.model_selection import RandomizedSearchCV

from sklearn.base import BaseEstimator, RegressorMixin 

import seaborn as sns

import matplotlib.pyplot as plt 

from sklearn.linear_model import LinearRegression

# %%
#Create a try and except clause using the the pd.read_csv() function in order to upload the
#csv file on a local and nonlocal computer.  Save the csv file as a dataframe under the variable
#df.
try:
    df = pd.read_csv('car_data.csv') 
except:
    df = pd.read_csv('/datasets/car_data.csv')

# %% [markdown]
# #### Data preparation

# %%
#Use the head() method in order to print the first five rows of the dataframe.
df.head()
# Out:
#         DateCrawled  Price VehicleType  RegistrationYear Gearbox  Power  \
# 0  24/03/2016 11:52    480         NaN              1993  manual      0
# 1  24/03/2016 10:58  18300       coupe              2011  manual    190
# 2  14/03/2016 12:52   9800         suv              2004    auto    163
# 3  17/03/2016 16:54   1500       small              2001  manual     75
# 4  31/03/2016 17:25   3600       small              2008  manual     69
#
#    Model  Mileage  RegistrationMonth  FuelType       Brand NotRepaired  \
# 0   golf   150000                  0    petrol  volkswagen         NaN
# 1    NaN   125000                  5  gasoline        audi         yes
# 2  grand   125000                  8  gasoline        jeep         NaN
# 3   golf   150000                  6    petrol  volkswagen          no
# 4  fabia    90000                  7  gasoline       skoda          no
#
#         DateCreated  NumberOfPictures  PostalCode          LastSeen
# 0  24/03/2016 00:00                 0       70435  07/04/2016 03:16
# 1  24/03/2016 00:00                 0       66954  07/04/2016 01:46
# 2  14/03/2016 00:00                 0       90480  05/04/2016 12:47
# 3  17/03/2016 00:00                 0       91074  17/03/2016 17:40
# 4  31/03/2016 00:00                 0       60437  06/04/2016 10:17

# %% [markdown]
# Code Result:
# It seems that the titles of the dataframe need to be converted to lowercase.  There also seems to be missing
# values in several columns of the dataframe.

# %%
#Use the rename() method nin order to rename the columns of the dataframe appropriately.
df = df.rename(columns={'DateCrawled': 'date_crawled',
                        'Price': 'price',
                         'VehicleType': 'vehicle_type',
                         'RegistrationYear': 'registration_year',
                         'Gearbox': 'gearbox',
                         'Power': 'power',
                         'Model': 'model',
                         'Mileage': 'mileage',
                         'RegistrationMonth': 'registration_month',
                         'FuelType': 'fuel_type',
                         'Brand': 'brand',
                         'NotRepaired': 'not_repaired',
                         'DateCreated': 'date_created',
                         'NumberOfPictures': 'number_of_pictures',
                         'PostalCode': 'postal_code',
                         'LastSeen': 'last_seen'})

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <h2>   Reviewer's comment </h2>
#
# Good!
#
# </div>

# %%
#Use the info method in order to check the datatypes of the dataframe.
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 354369 entries, 0 to 354368
# Data columns (total 16 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   date_crawled        354369 non-null  object
#  1   price               354369 non-null  int64
#  2   vehicle_type        316879 non-null  object
#  3   registration_year   354369 non-null  int64
#  4   gearbox             334536 non-null  object
#  5   power               354369 non-null  int64
#  6   model               334664 non-null  object
#  7   mileage             354369 non-null  int64
#  8   registration_month  354369 non-null  int64
#  9   fuel_type           321474 non-null  object
#  10  brand               354369 non-null  object
#  11  not_repaired        283215 non-null  object
#  12  date_created        354369 non-null  object
#  13  number_of_pictures  354369 non-null  int64
#  14  postal_code         354369 non-null  int64
#  15  last_seen           354369 non-null  object
# dtypes: int64(7), object(9)
# memory usage: 43.3+ MB

# %% [markdown]
# Code Result:
# It appears that the date_crawled, date_created and last_seen columns need to be converted from
# the object to the datetime64 data type.

# %%
#Use the pd.to_datetime() method in order to convert the date_crawled, date_created and
#last_seen columns to the datetime64 data type.
df['date_crawled'] = pd.to_datetime(df['date_crawled'], errors='coerce') 
df['date_created'] = pd.to_datetime(df['date_created'], errors='coerce') 
df['last_seen'] = pd.to_datetime(df['last_seen'], errors='coerce')
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_14648\304031342.py:3: UserWarning: Parsing dates in %d/%m/%Y %H:%M format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   df['date_crawled'] = pd.to_datetime(df['date_crawled'], errors='coerce')
# C:\Users\HP\AppData\Local\Temp\ipykernel_14648\304031342.py:4: UserWarning: Parsing dates in %d/%m/%Y %H:%M format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   df['date_created'] = pd.to_datetime(df['date_created'], errors='coerce')

# %%
#Use the info() method once again in order to double check the columns of the dataframe.
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 354369 entries, 0 to 354368
# Data columns (total 16 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   date_crawled        354369 non-null  datetime64[ns]
#  1   price               354369 non-null  int64
#  2   vehicle_type        316879 non-null  object
#  3   registration_year   354369 non-null  int64
#  4   gearbox             334536 non-null  object
#  5   power               354369 non-null  int64
#  6   model               334664 non-null  object
#  7   mileage             354369 non-null  int64
#  8   registration_month  354369 non-null  int64
#  9   fuel_type           321474 non-null  object
#  10  brand               354369 non-null  object
#  11  not_repaired        283215 non-null  object
#  12  date_created        354369 non-null  datetime64[ns]
#  13  number_of_pictures  354369 non-null  int64
#  14  postal_code         354369 non-null  int64
#  15  last_seen           228151 non-null  datetime64[ns]
# dtypes: datetime64[ns](3), int64(7), object(6)
# memory usage: 43.3+ MB

# %% [markdown]
# Code Result:
# It appears that the date_crawled, date_created and last_seen columns were converted from the object type to
# the datetime64 data type successfully.

# %%
#Create a function to convert the entries in the not_repaired column to entries for a repaired column.
def convert_repaired(row_entry):
    if row_entry == 'yes':
        return 'no'
    elif row_entry == 'no':
        return 'yes'
    else:
        return 'unknown'

#Use the apply() method and the convert_repaired() function to create repaired column 
#for the dataframe.
df['repaired'] = df['not_repaired'].apply(convert_repaired)

# %% [markdown]
# Code Rationale:
# The name of the 'not_repaired' column is a bit confusing.  I have created a column named 'reparied' with converted values from the 'not_repaired' column for more clarity.

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <h2>   Reviewer's comment </h2>
#
# Agreed.
# </div>

# %%
#Use the describe() method in order to check the dataframe for any zero or negative outlier values.
df.describe()
# Out:
#                         date_crawled          price  registration_year  \
# count                         354369  354369.000000      354369.000000
# mean   2016-03-21 12:57:41.165057280    4416.656776        2004.234448
# min              2016-03-05 14:06:00       0.000000        1000.000000
# 25%              2016-03-13 11:52:00    1050.000000        1999.000000
# 50%              2016-03-21 17:50:00    2700.000000        2003.000000
# 75%              2016-03-29 14:37:00    6400.000000        2008.000000
# max              2016-04-07 14:36:00   20000.000000        9999.000000
# std                              NaN    4514.158514          90.227958
#
#                power        mileage  registration_month  \
# count  354369.000000  354369.000000       354369.000000
# mean      110.094337  128211.172535            5.714645
# min         0.000000    5000.000000            0.000000
# 25%        69.000000  125000.000000            3.000000
# 50%       105.000000  150000.000000            6.000000
# 75%       143.000000  150000.000000            9.000000
# max     20000.000000  150000.000000           12.000000
# std       189.850405   37905.341530            3.726421
#
#                         date_created  number_of_pictures    postal_code  \
# count                         354369            354369.0  354369.000000
# mean   2016-03-20 19:12:07.753274112                 0.0   50508.689087
# min              2014-03-10 00:00:00                 0.0    1067.000000
# 25%              2016-03-13 00:00:00                 0.0   30165.000000
# 50%              2016-03-21 00:00:00                 0.0   49413.000000
# 75%              2016-03-29 00:00:00                 0.0   71083.000000
# max              2016-04-07 00:00:00                 0.0   99998.000000
# std                              NaN                 0.0   25783.096248
#
#                            last_seen
# count                         228151
# mean   2016-06-02 09:26:42.824005888
# min              2016-01-04 00:15:00
# 25%              2016-05-04 15:47:00
# 50%              2016-06-04 10:16:00
# 75%              2016-07-04 03:45:00
# max              2016-12-03 23:54:00
# std                              NaN

# %% [markdown]
# Code Result:
# It appears that there are a significant number of zero or negative values in the: price, power, registration_month,
# and number_of_pictures columns.  I will filter out the zero and negative values for the columns that I decide to keep
# in the upcoming EDA section of this project and I will drop the uneccessary columns with these outlier values.

# %%
#Use the isna() and sum() methods in order to check for missing values in the dataframe.
df.isna().sum()
# Out:
# date_crawled               0
# price                      0
# vehicle_type           37490
# registration_year          0
# gearbox                19833
# power                      0
# model                  19705
# mileage                    0
# registration_month         0
# fuel_type              32895
# brand                      0
# not_repaired           71154
# date_created               0
# number_of_pictures         0
# postal_code                0
# last_seen             126218
# repaired                   0
# dtype: int64

# %% [markdown]
# Code Result:
# It appears that there are missing values in several columns of the dataframe.  I will fill these
# missing values with the string, 'unknown' in the cell below.

# %%
#Use the dropna() method in order to drop the other missing values in the dataframe.
df.fillna('unknown', inplace=True) 

df.isna().sum()
# Out:
# date_crawled          0
# price                 0
# vehicle_type          0
# registration_year     0
# gearbox               0
# power                 0
# model                 0
# mileage               0
# registration_month    0
# fuel_type             0
# brand                 0
# not_repaired          0
# date_created          0
# number_of_pictures    0
# postal_code           0
# last_seen             0
# repaired              0
# dtype: int64

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <h2>   Reviewer's comment 3</h2>
#
# Makes sense! 😊
#
# </div><div class="alert alert-danger" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b>   Reviewer's comment 2</b>
#
# You dropped missing values in the code cell #9. Please always check the results. Here, for example, it may be a good idea to print the length of the dataframe.
#
#
#
# </div>

# %% [markdown]
# <div class="alert alert-danger" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b>   Reviewer's comment </b>
#
# Please don't drop more than 10% of data. Instead, replace missing values with some unique row, such as "Unknown".
#
#
# </div>

# %% [markdown]
# #### Note To Reviewer:
# Here is my revised code.

# %% [markdown]
# Code Result:
# There are no longer any missing values noted in the dataframe.  The missing values were successfully filled or dropped
# appropriately.

# %%
#Use the dupliated() and sum() methods in order to count the amount of duplicate values in the dataframe.
df.duplicated().sum()
# Out:
# 321

# %% [markdown]
# Code Result:
# There are 321 duplicate values noted in the dataframe.

# %%
#Use the drop_duplicates() method in order to drop the duplicate values from the dataframe.
df = df.drop_duplicates() 

#Use the dupliated() and sum() methods again in order dpuble check for duplicate values in the dataframe.
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# Code Result:
# There are no longer any duplicate values noted in the dataframe.  The duplicate values were successfully dropped.

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <h2>   Reviewer's comment 3</h2>
#
# Good.
# </div>

# %% [markdown]
# #### Creating New Features and Filtering Outliers

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 354048 entries, 0 to 354368
# Data columns (total 17 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   date_crawled        354048 non-null  datetime64[ns]
#  1   price               354048 non-null  int64
#  2   vehicle_type        354048 non-null  object
#  3   registration_year   354048 non-null  int64
#  4   gearbox             354048 non-null  object
#  5   power               354048 non-null  int64
#  6   model               354048 non-null  object
#  7   mileage             354048 non-null  int64
#  8   registration_month  354048 non-null  int64
#  9   fuel_type           354048 non-null  object
#  10  brand               354048 non-null  object
#  11  not_repaired        354048 non-null  object
#  12  date_created        354048 non-null  datetime64[ns]
#  13  number_of_pictures  354048 non-null  int64
#  14  postal_code         354048 non-null  int64
#  15  last_seen           354048 non-null  object
#  16  repaired            354048 non-null  object
# dtypes: datetime64[ns](2), int64(7), object(8)
# memory usage: 48.6+ MB

# %%
#Convert the last_seen column in the dataframe from object to datetime data type.
df['last_seen'] = pd.to_datetime(df['last_seen'], errors='coerce')

# %%
#Use dt.days in order to extract the number of days in the last_seen and date_created columns.
df['age_days'] = (df['last_seen'] - df['date_created']).dt.days 

#Use dt.days in order to extract the month number index in the date_crawled column.
df['month_crawled'] = df['date_crawled'].dt.month

#Use dt.days in order to extract the day of the week number index in the date_created column.
df['dayofweek_created'] = df['date_created'].dt.weekday

# %%
#Use the describe() method in order to check the min and max values of the dataframe.
df.describe()
# Out:
#                         date_crawled          price  registration_year  \
# count                         354048  354048.000000      354048.000000
# mean   2016-03-21 12:58:13.080938240    4416.413407        2004.235609
# min              2016-03-05 14:06:00       0.000000        1000.000000
# 25%              2016-03-13 11:52:00    1050.000000        1999.000000
# 50%              2016-03-21 17:51:00    2700.000000        2003.000000
# 75%              2016-03-29 14:37:00    6400.000000        2008.000000
# max              2016-04-07 14:36:00   20000.000000        9999.000000
# std                              NaN    4514.409880          90.268665
#
#                power        mileage  registration_month  \
# count  354048.000000  354048.000000       354048.000000
# mean      110.088833  128210.751085            5.714129
# min         0.000000    5000.000000            0.000000
# 25%        69.000000  125000.000000            3.000000
# 50%       105.000000  150000.000000            6.000000
# 75%       143.000000  150000.000000            9.000000
# max     20000.000000  150000.000000           12.000000
# std       189.929742   37907.872536            3.726710
#
#                         date_created  number_of_pictures    postal_code  \
# count                         354048            354048.0  354048.000000
# mean   2016-03-20 19:12:38.703904768                 0.0   50506.806114
# min              2014-03-10 00:00:00                 0.0    1067.000000
# 25%              2016-03-13 00:00:00                 0.0   30165.000000
# 50%              2016-03-21 00:00:00                 0.0   49406.000000
# 75%              2016-03-29 00:00:00                 0.0   71083.000000
# max              2016-04-07 00:00:00                 0.0   99998.000000
# std                              NaN                 0.0   25784.636959
#
#                            last_seen       age_days  month_crawled  \
# count                         227980  227980.000000  354048.000000
# mean   2016-06-02 09:23:01.375383552      71.374910       3.162376
# min              2016-01-04 00:15:00     -88.000000       3.000000
# 25%              2016-05-04 15:47:00      38.000000       3.000000
# 50%              2016-06-04 10:16:00      68.000000       3.000000
# 75%              2016-07-04 03:45:00      96.000000       3.000000
# max              2016-12-03 23:54:00     847.000000       4.000000
# std                              NaN      71.404907       0.368796
#
#        dayofweek_created
# count      354048.000000
# mean            2.891616
# min             0.000000
# 25%             1.000000
# 50%             3.000000
# 75%             5.000000
# max             6.000000
# std             2.075828

# %% [markdown]
# Code Result:
# It appears that the minimum registration_year entry is 1000, which is not a suitable entry because cars did not
# exist in the year 1000.  The maximum registration_year entry is 9999, which is not a suitable entry because the max
# entry for the date_crawled column contains an entry from the year 2016.

# %%
#Use the dt.year and max() methodsnin order to create a variable for the maximum crawl year.
max_crawl_year = df['date_crawled'].dt.year.max() 

#Use conditional filtering in order to filter out rows in the registration_year column that
#are not less than or equal to max_crawl_year.
df = df[df['registration_year'] <= max_crawl_year] 

#Use conditional filtering in order to filter out rows in the registration_year column
#that are not greater than or equal to 1950(the maximum acceptable oldest year).
df = df[df['registration_year'] >= 1950]

# %%
#Use the describe() method in order to check the min and max values of the dataframe.
df.describe()
# Out:
#                         date_crawled          price  registration_year  \
# count                         339273  339273.000000      339273.000000
# mean   2016-03-21 12:46:55.835920128    4471.354549        2002.524816
# min              2016-03-05 14:06:00       0.000000        1950.000000
# 25%              2016-03-13 11:42:00    1099.000000        1999.000000
# 50%              2016-03-21 17:48:00    2799.000000        2003.000000
# 75%              2016-03-29 14:37:00    6500.000000        2007.000000
# max              2016-04-07 14:36:00   20000.000000        2016.000000
# std                              NaN    4545.534525           6.836567
#
#                power        mileage  registration_month  \
# count  339273.000000  339273.000000       339273.000000
# mean      111.040702  128123.502312            5.757988
# min         0.000000    5000.000000            0.000000
# 25%        69.000000  125000.000000            3.000000
# 50%       105.000000  150000.000000            6.000000
# 75%       143.000000  150000.000000            9.000000
# max     20000.000000  150000.000000           12.000000
# std       186.981005   37844.961731            3.707903
#
#                         date_created  number_of_pictures    postal_code  \
# count                         339273            339273.0  339273.000000
# mean   2016-03-20 18:59:21.004854528                 0.0   50605.178269
# min              2014-03-10 00:00:00                 0.0    1067.000000
# 25%              2016-03-13 00:00:00                 0.0   30169.000000
# 50%              2016-03-21 00:00:00                 0.0   49492.000000
# 75%              2016-03-29 00:00:00                 0.0   71229.000000
# max              2016-04-07 00:00:00                 0.0   99998.000000
# std                              NaN                 0.0   25807.037835
#
#                            last_seen       age_days  month_crawled  \
# count                         219202  219202.000000  339273.000000
# mean   2016-06-02 10:26:23.881260032      71.436981       3.162380
# min              2016-01-04 00:15:00     -88.000000       3.000000
# 25%              2016-05-04 16:36:00      38.000000       3.000000
# 50%              2016-06-04 10:16:00      68.000000       3.000000
# 75%              2016-07-04 03:45:00      96.000000       3.000000
# max              2016-12-03 23:54:00     847.000000       4.000000
# std                              NaN      71.146572       0.368799
#
#        dayofweek_created
# count      339273.000000
# mean            2.891660
# min             0.000000
# 25%             1.000000
# 50%             3.000000
# 75%             5.000000
# max             6.000000
# std             2.076117

# %%
#Use the drop() method in order to drop unncessary columns in the df_dataframe before EDA.
df = df.drop(columns=['number_of_pictures', 'last_seen', 'not_repaired', 'date_crawled', 'postal_code', 'date_created'])

# %%
#Use the head() method in order to check the first five lines of the df_dataframe.
df.head()
# Out:
#    price vehicle_type  registration_year gearbox  power    model  mileage  \
# 0    480      unknown               1993  manual      0     golf   150000
# 1  18300        coupe               2011  manual    190  unknown   125000
# 2   9800          suv               2004    auto    163    grand   125000
# 3   1500        small               2001  manual     75     golf   150000
# 4   3600        small               2008  manual     69    fabia    90000
#
#    registration_month fuel_type       brand repaired  age_days  month_crawled  \
# 0                   0    petrol  volkswagen  unknown     102.0              3
# 1                   5  gasoline        audi       no     102.0              3
# 2                   8  gasoline        jeep  unknown      51.0              3
# 3                   6    petrol  volkswagen      yes       NaN              3
# 4                   7  gasoline       skoda      yes      65.0              3
#
#    dayofweek_created
# 0                  3
# 1                  3
# 2                  0
# 3                  3
# 4                  3

# %% [markdown]
# Code Result:
# The unneccesary colums of the df dataframe were successfully dropped.

# %%
#Use the describe() method in order to check for zero or negative values in the dataframe.
df.describe()
# Out:
#                price  registration_year          power        mileage  \
# count  339273.000000      339273.000000  339273.000000  339273.000000
# mean     4471.354549        2002.524816     111.040702  128123.502312
# std      4545.534525           6.836567     186.981005   37844.961731
# min         0.000000        1950.000000       0.000000    5000.000000
# 25%      1099.000000        1999.000000      69.000000  125000.000000
# 50%      2799.000000        2003.000000     105.000000  150000.000000
# 75%      6500.000000        2007.000000     143.000000  150000.000000
# max     20000.000000        2016.000000   20000.000000  150000.000000
#
#        registration_month       age_days  month_crawled  dayofweek_created
# count       339273.000000  219202.000000  339273.000000      339273.000000
# mean             5.757988      71.436981       3.162380           2.891660
# std              3.707903      71.146572       0.368799           2.076117
# min              0.000000     -88.000000       3.000000           0.000000
# 25%              3.000000      38.000000       3.000000           1.000000
# 50%              6.000000      68.000000       3.000000           3.000000
# 75%              9.000000      96.000000       3.000000           5.000000
# max             12.000000     847.000000       4.000000           6.000000

# %% [markdown]
# Code Result:
# It appears that there are zero values in the: price, power, registration_month, and dayofweek_created columns of the df
# dataframe.  There are also negative values noted in the age_days column of the dataframe as well.  These values must be removed.

# %%
#Use conditional filtering in order to filter out negative and zero values from the appropriate columns of the dataframe.
df = df[df['price'] > 1]
df = df[df['power'] > 1]
df = df[df['registration_month'] > 0] 
df = df[df['age_days'] > 0] 
df = df[df['dayofweek_created'] > 0 ]

#Use the describe() method once again in order to double check for zero or negative values in the dataframe.
df.describe()
# Out:
#                price  registration_year          power        mileage  \
# count  130046.000000      130046.000000  130046.000000  130046.000000
# mean     5567.663135        2003.178491     126.463344  125692.908663
# std      4883.416462           6.631371     161.352245   38184.400744
# min         3.000000        1950.000000       2.000000    5000.000000
# 25%      1650.000000        1999.000000      82.000000  100000.000000
# 50%      3950.000000        2004.000000     116.000000  150000.000000
# 75%      8250.000000        2008.000000     150.000000  150000.000000
# max     20000.000000        2016.000000   19312.000000  150000.000000
#
#        registration_month       age_days  month_crawled  dayofweek_created
# count       130046.000000  130046.000000  130046.000000      130046.000000
# mean             6.377413      87.922143       3.221460           3.583563
# std              3.340294      58.965775       0.415231           1.754526
# min              1.000000       1.000000       3.000000           1.000000
# 25%              4.000000      55.000000       3.000000           2.000000
# 50%              6.000000      74.000000       3.000000           4.000000
# 75%              9.000000     101.000000       3.000000           5.000000
# max             12.000000     332.000000       4.000000           6.000000

# %%
#Use the isna() and sum() methods in order to double check for missing values in the df dataframe.
df.isna().sum()
# Out:
# price                 0
# vehicle_type          0
# registration_year     0
# gearbox               0
# power                 0
# model                 0
# mileage               0
# registration_month    0
# fuel_type             0
# brand                 0
# repaired              0
# age_days              0
# month_crawled         0
# dayofweek_created     0
# dtype: int64

# %% [markdown]
# Code Result:
# There are no missing values noted in the df dataframe.

# %%
#Use the duplicated() and sum() methods to check for duplicate values in the df dataframe.
df.duplicated().sum()
# Out:
# 3243

# %% [markdown]
# Code Result:
# There are 3,243 duplicate values noted in the df dataframe after dropping zero and negative values.  These duplicate
# values will be dropped in the cell below.

# %%
#Use the drop_duplicates() method in order to drop duplicate values in the df_dataframe.
df = df.drop_duplicates()

# %%
#Use the duplicated() and sum() methods to double check for duplicate values in the df dataframe.
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# Code Result:
# There are no longer any duplicate values noted in the df dataframe.  The duplicate values were successfully dropped.

# %%
#Create an index for the numerical features of the dataframe.
numerical_features  = ['registration_year',
                      'power',
                      'mileage',
                      'age_days',
                      'dayofweek_created',
                      'month_crawled'] 

outlier_columns = numerical_features + ['price']

def remove_outliers(df, outlier_columns):
    # Define the Q1 and Q3 quantile values using the quantile() method for numerical columns.
    Q1 = df[outlier_columns].quantile(0.25)
    Q3 = df[outlier_columns].quantile(0.75)
    # Calculate the interquartile range (IQR).
    IQR = Q3 - Q1

    # Calculate lower and upper boundaries for outliers.
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR

    # Create a mask for numerical features, filtering out the outliers.
    mask = (df[outlier_columns] >= lower_bound) & (df[outlier_columns] <= upper_bound)

    # Retain rows without outliers, but keep all original columns (including categorical ones).
    df_cleaned = df[mask.all(axis=1)].copy()

    return df_cleaned

df_cleaned = remove_outliers(df, outlier_columns)

# %% [markdown]
# <div class="alert alert-warning" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b>   Reviewer's comment 2 </b>
#
#
# IQR is often used to determine outliers in the normal distribution. Please keep in mind that not everything outside the boxplot whiskers is outlier. Likewise, not everything within whiskers is a normal data. This is because the whisker goes either to the maximum (minimum) or to 1.5 times the length of the box. The concentration of circles after the whiskers can be very high. Cutting off the whiskers, we can sometimes lose important information, as our sample can be really biased.
#
#
# </div>
# <div class="alert alert-danger" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Reviewer's comment  2 </b>
#
# Always check the result. Let's print the minimum value:
# </div>

# %%
#Use the describe() method in order to examine the quantile values in the column of the dataframe.
df_cleaned.describe()
# Out:
#               price  registration_year         power        mileage  \
# count  78386.000000       78386.000000  78386.000000   78386.000000
# mean    5284.475021        2003.452976    119.812798  128437.731228
# std     4441.786112           5.663045     45.835156   34147.260456
# min        3.000000        1986.000000      2.000000   30000.000000
# 25%     1650.000000        1999.000000     82.000000  125000.000000
# 50%     3900.000000        2004.000000    116.000000  150000.000000
# 75%     7900.000000        2008.000000    150.000000  150000.000000
# max    18100.000000        2016.000000    253.000000  150000.000000
#
#        registration_month      age_days  month_crawled  dayofweek_created
# count        78386.000000  78386.000000        78386.0       78386.000000
# mean             6.377861     75.634322            3.0           3.349284
# std              3.343259     27.798139            0.0           1.736240
# min              1.000000      1.000000            3.0           1.000000
# 25%              3.000000     57.000000            3.0           2.000000
# 50%              6.000000     74.000000            3.0           3.000000
# 75%              9.000000     96.000000            3.0           5.000000
# max             12.000000    169.000000            3.0           6.000000

# %% [markdown]
# Code Result:
# There are no negative or zero values noted in the dataset.

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <h2>   Reviewer's comment 3</h2>
#
# > Code Result: There are no negative or zero values noted in the dataset.
#
#
# Correct!
# </div>
# <div class="alert alert-danger" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <h2>   Reviewer's comment 3</h2>
#
# However, what about the minimum values? Take a look: min price value is 1, min power is 1. Moreover, please check max dates in the `RegistrationYear` and  `DateCrawled` columns. Vehicle should not be registered after the data was downloaded :) So the max `RegistrationYear` must not be larger than the max value in the  `DateCrawled`.
#
# </div>

# %% [markdown]
# Note to Reviewer On Reviewer's Comment 3:
# I fixed the issues with this comment in the cells above.

# %% [markdown]
# <div class="alert alert-danger" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b>   Reviewer's comment 2 </b>
#
# Don't forget to check the result. As I've already mentioned, outliers can be inside IQR. Use the `describe` method please.
# </div>

# %% [markdown]
# <div class="alert alert-warning" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Reviewer's comment  2 </b>
#
# You can save these values and replace them with median price in groupping by model and registration year. Yes, registration year does not define the vehicle's age, but still.
#
# </div>

# %%
df_cleaned.isna().sum()
# Out:
# price                 0
# vehicle_type          0
# registration_year     0
# gearbox               0
# power                 0
# model                 0
# mileage               0
# registration_month    0
# fuel_type             0
# brand                 0
# repaired              0
# age_days              0
# month_crawled         0
# dayofweek_created     0
# dtype: int64

# %% [markdown]
# Code Result:
# It appears that there are no missing values noted in the df_cleaned dataframe.

# %%
#Use the duplicated() and sum() methods in order to check for duplicate values in the df_cleaned dataframe.
df_cleaned.duplicated().sum()
# Out:
# 0

# %% [markdown]
# Code Result:
# There are no duplicate values noted in the df_cleaned dataframe.

# %% [markdown]
# ##### Vehicle Price Distributions Histograms

# %%
#Use conditional filtering in order to create a dataframe that only consists of the price column of the df dataframe.
price_df = df[['price']] 

#Use conditional filtering in order to filter out zero and negative values from the price_df dataframe.
price_df = price_df[price_df['price'] > 0]

# %%
#Use sns.histplot() in order to make a histogram plot of the distribution of vehicle price
#amounts throughout the dataframe.
sns.histplot(price_df['price'])

plt.xlabel("Vehicle Price (Euros)") 

plt.title("Histogram Of Vehicle Price Distribution \n (With Outliers)")

plt.tight_layout

plt.show()

# %% [markdown]
# Histogram Conclusion:
# According to the histogram, the vehicle price entry with highest count is: approximately 1,500 Euros with a value count of:
# approximately 7,800.  The vehicle price entry with the lowest count is: approximately: 19,000 Euros with a value count of:
# approximately 100.

# %%
#Use sns.histplot() in order to make a histogram plot of the distribution of vehicle price
#amounts throughout the dataframe with outliers removed.
sns.histplot(df_cleaned['price'], color='red')

plt.xlabel("Vehicle Price (Euros)") 

plt.title("Histogram Of Vehicle Price Distribution \n (Outliers Removed)")

plt.tight_layout

plt.show()

# %% [markdown]
# Histogram Conclusion:
# According to the histogram, the vehicle price entry with highest count is: approximately 900 Euros with a value count of:
# approximately 4,600.  The vehicle price entry with the lowest count is: approximately: 17,900 Euros with a value count of:
# approximately 200.

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <h2> Reviewer's comment  2 </h2>
#
# Good!
#
# </div>
# <div class="alert alert-warning" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Reviewer's comment</b>
#
# KDE is not that helpful, so it's better to use a simple histogram.
#
# </div>

# %% [markdown]
# #### Note to Reviewer:
# This is my updated histogram.

# %% [markdown]
# #### Histogram of Vehicle Age

# %%
#Use sns.histplot() in order to make a histogram plot of the distribution of vehicle age
#entries throughout the dataframe with outliers removed.
sns.histplot(df_cleaned['age_days'], color='red')

plt.xlabel("Vehicle Age (Days)") 

plt.title("Histogram Of Vehicle Age Distribution \n (Outliers Removed)")

plt.tight_layout

plt.show()

# %% [markdown]
# Code Result:
# The vehicle age entry with the highest value count is: approximately 72 days old, with a value count of: approximately: 5,800.
# The vehicle age entry with the lowest value count is: approximately 5 days old, with a value count of: approximately: 100.

# %% [markdown]
# #### Note To Reviewer:
# I decided not to include a histogram of vehicle age distribution with outliers because the data was not clear.

# %% [markdown]
# ##### Average Vehicle Price Per Vehicle Type Boxplots

# %%
#Use conditional filtering in order to create a dataframe that only consists 
#of the vehicle_type and price columns of the df dataframe. 
v_type_df = df[['vehicle_type', 'price']] 

#Use conditional filtering in order to filter out zero and negative values from the v_type_df dataframe.
v_type_df = v_type_df[v_type_df['price'] > 0]

# %%
#Use sns.boxplot() in order to create a boxplot of average vehicle price
#per vehicle type.
vehicle_type_box = sns.boxplot(x=v_type_df['vehicle_type'], y=v_type_df['price']) 

plt.xlabel('Vehicle Type') 

plt.ylabel('Vehicle Price (Euros)') 
plt.title("Boxplot of Average Vehicle Price \n Per Vehicle Type (With Outliers)")

plt.xticks(rotation=45)

plt.show()

# %%
#Use sns.boxplot() in order to create a boxplot of average vehicle price
#per vehicle type.
vehicle_type_box = sns.boxplot(x=v_type_df['vehicle_type'], y=v_type_df['price']) 

plt.xlabel('Vehicle Type') 

plt.ylabel('Vehicle Price (Euros)') 
plt.title("Boxplot of Average Vehicle Price \n Per Vehicle Type (With Outliers)")

plt.xticks(rotation=45)
plt.ylim(0, 15000)
plt.show()

# %% [markdown]
# Boxplot Conclusion:
# According to the boxplot, the vehicle type with the highest median vehicle price value is: suv, with a median price value of:
# approximately 9,500 Euros.  The vehicle type with the lowest median price value is: small, with a median price value of:
# approximately: 2,100 Euros.

# %%
#Use sns.boxplot() in order to create a boxplot of average vehicle price
#per vehicle type.
vehicle_type_box_or = sns.boxplot(x=df_cleaned['vehicle_type'], y=df_cleaned['price']) 

plt.xlabel('Vehicle Type') 

plt.ylabel('Vehicle Price (Euros)') 
plt.title("Boxplot of Average Vehicle Price \n Per Vehicle Type (Outliers Removed)")
plt.tight_layout() 

plt.xticks(rotation=45)

plt.show()

# %%
#Use sns.boxplot() in order to create a boxplot of average vehicle price
#per vehicle type.
vehicle_type_box_or = sns.boxplot(x=df_cleaned['vehicle_type'], y=df_cleaned['price']) 

plt.xlabel('Vehicle Type') 

plt.ylabel('Vehicle Price (Euros)') 
plt.title("Boxplot of Average Vehicle Price \n Per Vehicle Type (Outliers Removed)")
plt.tight_layout() 

plt.xticks(rotation=45)
plt.ylim(0, 14000)
plt.show()

# %% [markdown]
# Chart Conclusion:
# Boxplot Conclusion:
# According to the boxplot, the vehicle type with the highest median vehicle price value is: suv, with a median price value of:
# approximately 9,100 Euros.  The vehicle type with the lowest median price value is: small, with a median price value of:
# approximately: 2,100 Euros.

# %% [markdown]
# ##### Average Vehicle Price Per Fuel Type Boxplots

# %%
#Use conditional filtering in order to create a dataframe that only consists of the 
#fuel_type and price columns of the df dataframe. 
v_fuel_df = df[['fuel_type', 'price']] 

#Use conditional filtering in order to filter out zero and negative values from the v_fuel_df dataframe.
v_fuel_df = v_fuel_df[v_fuel_df['price'] > 0]

# %%
#Use sns.boxplot() in order to create a boxplot of average vehicle price
#per fuel type.
vehicle_type_box = sns.boxplot(x=v_fuel_df['fuel_type'], y=v_fuel_df['price']) 

plt.xlabel('Fuel Type') 

plt.ylabel('Vehicle Price (Euros)') 
plt.title("Boxplot of Average Vehicle Price \n Per Fuel Type (With Outliers) ")

plt.xticks(rotation=45)
plt.show()

# %%
#Use sns.boxplot() in order to create a boxplot of average vehicle price
#per fuel type.
vehicle_type_box = sns.boxplot(x=v_fuel_df['fuel_type'], y=v_fuel_df['price']) 

plt.xlabel('Fuel Type') 

plt.ylabel('Vehicle Price (Euros)') 
plt.title("Boxplot of Average Vehicle Price \n Per Fuel Type (With Outliers)")

plt.ylim(0, 15000) 

plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# Chart Conclusion:
# Boxplot Conclusion:
# According to the boxplot, the fuel type with the highest median vehicle price value is: hybrid, with a median price value of:
# approximately 11,200 Euros.  The fuel type with the lowest median price value is: other, with a median price value of:
# approximately: 1,900 Euros.

# %%
#Use sns.boxplot() in order to create a boxplot of average vehicle price
#per fuel type.
vehicle_type_box = sns.boxplot(x=df_cleaned['fuel_type'], y=df_cleaned['price']) 

plt.xlabel('Fuel Type') 

plt.ylabel('Vehicle Price (Euros)') 
plt.title("Boxplot of Average Vehicle Price \n Per Fuel Type (With Outliers Removed) ")

plt.xticks(rotation=45)
plt.show()

# %%
#Use sns.boxplot() in order to create a boxplot of average vehicle price
#per fuel type.
vehicle_type_box = sns.boxplot(x=df_cleaned['fuel_type'], y=df_cleaned['price']) 

plt.xlabel('Fuel Type') 

plt.ylabel('Vehicle Price (Euros)') 
plt.title("Boxplot of Average Vehicle Price \n Per Fuel Type (With Outliers Removed) ")

plt.ylim(0, 14000)
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# Boxplot Conclusion:
# According to the boxplot, the fuel type with the highest median vehicle price value is: hybrid, with a median price value of:
# approximately 11,100 Euros.  The fuel type with the lowest median price value is: other, with a median price value of:
# approximately: 1,900 Euros.

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <h2> Reviewer's comment  </h2>
#
# Use `\` or `\\` before the `$` character. Then `\$27` will be displayed correctly: \$27.
#
#
# </div>

# %% [markdown]
# ##### Average Vehicle Price Based On Gearbox Type Boxplots

# %%
#Use conditional filtering in order to create a dataframe that only consists of the 
#gearbox and price columns of the df dataframe. 
v_gear_df = df[['gearbox', 'price']] 

#Use conditional filtering in order to filter out zero and negative values from the v_gear_df dataframe.
v_gear_df = v_gear_df[v_gear_df['price'] > 0]

# %%
#Use sns.boxplot() in order to create a boxplot of average vehicle price
#gearbox type.
gearbox_box = sns.boxplot(x=v_gear_df['gearbox'], y=v_gear_df['price']) 

plt.xlabel('Gearbox') 

plt.ylabel('Vehicle Price (Euros)') 
plt.title("Boxplot of Average Vehicle Price \n Based On Gearbox Type (With Outliers)")

plt.show()

# %%
#Use sns.boxplot() in order to create a boxplot of average vehicle price
#gearbox type.
gearbox_box = sns.boxplot(x=v_gear_df['gearbox'], y=v_gear_df['price']) 

plt.xlabel('Gearbox') 

plt.ylabel('Vehicle Price (Euros)') 
plt.title("Boxplot of Average Vehicle Price \n Based On Gearbox Type (With Outliers)")

plt.ylim(0, 12500)
plt.show()

# %% [markdown]
# Chart Conclusion:
# According to the boxplot, cars with the auto gearbox type have a higher median vehicle price (approximately 6,900 Euros)
# than cars with the manual gearbox type (approximately 3,700 Euros).

# %%
#Use sns.boxplot() in order to create a boxplot of average vehicle price
#gearbox type.
gearbox_box = sns.boxplot(x=df_cleaned['gearbox'], y=df_cleaned['price']) 

plt.xlabel('Gearbox') 

plt.ylabel('Vehicle Price (Euros)') 
plt.title("Boxplot of Average Vehicle Price \n Based On Gearbox Type (With Outliers Removed)")

plt.show()

# %%
#Use sns.boxplot() in order to create a boxplot of average vehicle price
#gearbox type.
gearbox_box = sns.boxplot(x=df_cleaned['gearbox'], y=df_cleaned['price']) 

plt.xlabel('Gearbox') 

plt.ylabel('Vehicle Price (Euros)') 
plt.title("Boxplot of Average Vehicle Price \n Based On Gearbox Type (With Outliers Removed)")

plt.ylim(0, 12000)
plt.show()

# %% [markdown]
# Chart Conclusion:
# According to the boxplot, cars with the auto gearbox type have a higher median vehicle price (approximately 6,100 Euros)
# than cars with the manual gearbox type (approximately 3,700 Euros).

# %% [markdown]
# ##### Average Vehicle Price Based On Repair Status Boxplots

# %%
#Create a dataframe that only consists of the repaired and price columns of the df dataframe.
v_repaired_df = df[['repaired', 'price']] 

#Use conditional filtering in order to remove zero and negative values from the price column of the dataframe.
v_repaired_df = v_repaired_df[v_repaired_df['price'] > 0]

# %%
#Use sns.boxplot() in order to create a boxplot of average vehicle price
#based on repair status.
repaired_box = sns.boxplot(x=v_repaired_df['repaired'], y=v_repaired_df['price']) 

plt.xlabel('Repair Status') 

plt.ylabel('Vehicle Price (Euros)') 
plt.title("Boxplot of Average Vehicle Price \n Based On Repair Status (With Outliers)")

plt.show()

# %%
#Use sns.boxplot() in order to create a boxplot of average vehicle price
#based on repair status.
repaired_box = sns.boxplot(x=v_repaired_df['repaired'], y=v_repaired_df['price']) 

plt.xlabel('Repair Status') 

plt.ylabel('Vehicle Price (Euros)') 
plt.title("Boxplot of Average Vehicle Price \n Based On Repair Status (With Outliers)")

plt.ylim(0, 10000)
plt.show()

# %% [markdown]
# Chart Conclusion:
# According to the boxplot, cars with the 'yes' repaired status have a higher median vehicle price (approximately 4,600 Euros)
# than cars with the 'no' repaired status (approximately 1,000 Euros).

# %%
#Use sns.boxplot() in order to create a boxplot of average vehicle price
#based on repair status.
repaired_box = sns.boxplot(x=df_cleaned['repaired'], y=df_cleaned['price']) 

plt.xlabel('Repair Status') 

plt.ylabel('Vehicle Price (Euros)') 
plt.title("Boxplot of Average Vehicle Price \n Based On Repair Status (With Outliers Removed)")

plt.show()

# %%
#Use sns.boxplot() in order to create a boxplot of average vehicle price
#based on repair status.
repaired_box = sns.boxplot(x=df_cleaned['repaired'], y=df_cleaned['price']) 

plt.xlabel('Repair Status') 

plt.ylabel('Vehicle Price (Euros)') 
plt.title("Boxplot of Average Vehicle Price \n Based On Repair Status (With Outliers Removed)")

plt.ylim(0, 9000)
plt.show()

# %% [markdown]
# Chart Conclusion:
# According to the boxplot, cars with the 'yes' repaired status have a higher median vehicle price (approximately 4,400 Euros)
# than cars with the 'no' repaired status (approximately 1,100 Euros).

# %% [markdown]
# <div class="alert alert-danger" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Reviewer's comment 2 </b>
#
# What about `power` column?</div>
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <h2>   Reviewer's comment 3</h2>
#
# I've already left a comment about this column, so I will not repeat it here :)
# </div>

# %% [markdown]
# #### Vehicle Power Distribution

# %%
#Use sns.histplot() in order to make a KDE plot of the distribution of vehicle power
#values throughout the dataframe.
sns.histplot(df_cleaned['power'], color='red')

plt.xlabel("Vehicle Power (hp)") 

plt.title("Histogram Of Vehicle Power Distribution \n (Outliers Removed)")

plt.tight_layout

plt.show()

# %% [markdown]
# Histogram Conclusion:
# According to the histogram, the vehicle power entry with highest count is: approximately 76 hp, with a value count of:
# approximately 5,800.  The vehicle price entry with the lowest count is: approximately: 10 hp with a value count of:
# approximately 100.
#
# Important Note:
# I wanted to include a vehicle power histogram with the presence out outliers, but the outliers in the dataset made the histogram
# very hard to interpret. So, I decided to omit this histogram.

# %% [markdown]
# <div class="alert alert-danger" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Reviewer's comment </b>
#
# - Are there any outliers in the data? Drop abnormal values if they exist.
#
#
#
# - There are irrelevant columns. Let's drop them as well to decrease the number of features.
#
#
# - After removing unnecessary columns, it makes sense to check the data for duplicates again, as the dataset will later be splitted into training and test sets. You can also check it below, after you choose the columns you are going to use.
# </div>

# %% [markdown]
# #### Column Encoding

# %% [markdown]
# <div class="alert alert-danger" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Reviewer's comment 2 </b>
#
# Shouldn't you use the dataframe without outliers you created earlier?
# </div>

# %% [markdown]
# #### Note To Reviewer:
# I decided to delete the previous dataframes and create a totally new one.

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <h2>   Reviewer's comment 3</h2>
#
# > I decided to delete the previous dataframes and create a totally new one.
#
#
# Understood! :) </div>

# %% [markdown]
# <div class="alert alert-danger" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b>   Reviewer's comment 2</b>
#
# After removing unnecessary columns, it makes sense to check the data for duplicates again, as the dataset will later be splitted into training and test sets. Removing specific columns can cause previously distinct rows to become identical. If a dropped column contained unique values (ID or timestamp), removing it may make multiple rows appear the same.
#
# </div>

# %%
# Define the categorical, numerical, and target columns.
categorical_features = ['vehicle_type', 
                        'gearbox',
                        'model',
                        'fuel_type',
                        'brand',
                        'repaired']

numerical_features = ['registration_year',
                      'power',
                      'mileage',
                      'age_days',
                      'dayofweek_created',
                      'month_crawled']

target = ['price']

# Separate the categorical, numerical, and target data.
X_categorical = df_cleaned[categorical_features]
X_numerical = df_cleaned[numerical_features]
y_target = df_cleaned[target]

# Apply OneHotEncoder directly to the categorical columns.
#Use a try and except method in order to run the code on a local or non-local computer.
try:
    encoder = OneHotEncoder(sparse_output=False)
except:
    encoder = OneHotEncoder(sparse=False)

#Use the fit_transform() method in order to train the encoder with the X_categorical data.
X_encoded = encoder.fit_transform(X_categorical)

# Convert the encoded data into a DataFrame with aligned indices using he get_feature_names_out() method.
encoded_columns = encoder.get_feature_names_out(categorical_features)

#Use the pd.DataFrame() method to create the df_encoded_categorical dataframe.
df_encoded_categorical = pd.DataFrame(X_encoded, columns=encoded_columns, index=df_cleaned.index)

# Concatenate the encoded categorical features, numerical features, and target using the pd.concat() method.
df_encoded = pd.concat([df_encoded_categorical, X_numerical, y_target], axis=1)

#Use the head() method in order to display the first five rows of the df_encoded dataframe.
print(df_encoded.head())
# Out:
#     vehicle_type_bus  vehicle_type_convertible  vehicle_type_coupe  \
# 4                0.0                       0.0                 0.0
# 10               0.0                       0.0                 0.0
# 17               0.0                       0.0                 0.0
# 18               1.0                       0.0                 0.0
# 21               0.0                       0.0                 0.0
#
#     vehicle_type_other  vehicle_type_sedan  vehicle_type_small  \
# 4                  0.0                 0.0                 1.0
# 10                 0.0                 1.0                 0.0
# 17                 0.0                 0.0                 1.0
# 18                 0.0                 0.0                 0.0
# 21                 0.0                 1.0                 0.0
#
#     vehicle_type_suv  vehicle_type_unknown  vehicle_type_wagon  gearbox_auto  \
# 4                0.0                   0.0                 0.0           0.0
# 10               0.0                   0.0                 0.0           0.0
# 17               0.0                   0.0                 0.0           1.0
# 18               0.0                   0.0                 0.0           0.0
# 21               0.0                   0.0                 0.0           1.0
#
#     ...  repaired_no  repaired_unknown  repaired_yes  registration_year  \
# 4   ...          0.0               0.0           1.0               2008
# 10  ...          0.0               0.0           1.0               2004
# 17  ...          0.0               0.0           1.0               2004
# 18  ...          0.0               0.0           1.0               2007
# 21  ...          0.0               0.0           1.0               2002
#
#     power  mileage  age_days  dayofweek_created  month_crawled  price
# 4      69    90000      65.0                  3              3   3600
# 10    105   150000      70.0                  5              3   2000
# 17     75   150000      76.0                  6              3   1750
# 18    136   150000      42.0                  2              3   7550
# 21    231   150000      99.0                  6              3   3699
#
# [5 rows x 313 columns]

# %% [markdown]
# Code Result:
# The df_encoded dataframe was successfully created and the categorical variables were successfully encoded.

# %% [markdown]
# <div class="alert alert-danger" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b>   Reviewer's comment 2 </b>
#
# The cell above does not work.
# </div>

# %% [markdown]
# Note to Reviewer:
# This reviwer's not was related to the code:
# encoder = OneHotEncoder(sparse_output=False)
#
# I attempted to fix the code by creating this try and except statement:
#
# try:
#     encoder = OneHotEncoder(sparse_output=False)
# except:
#     encoder = OneHotEncoder(sparse=False)

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <h2>   Reviewer's comment 3 </h2>
#
# Makes sense! I also ran your project on my local device, since the kernel here cannot handle heavy projects sometimes.
#
# </div>

# %% [markdown]
# <div class="alert alert-danger" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b>   Reviewer's comment 2 </b>
#
# Please make sure you correctly merge dataframe. New missing values should not appear. </div>

# %%
#Use the isna() and sum() methods in order to check for missing values in the dataframe.
#Assign the code to na_sum variable.
na_sum = df_encoded.isna().sum()

#Create a for loop that prints out rows in the dataframe with missing values entries greater than 0.
for i in na_sum.index:
    if na_sum[i]>0:
        print(i,na_sum[i])

# %% [markdown]
# Code Result:
# The for loop does not print out any rows with missing values entries greater than 0.  It appears that there are no missing values in the df_encoded dataframe.  The dataframe was sucessfully merged.

# %% [markdown]
# <div class="alert alert-warning" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <h2>   Reviewer's comment 3 </h2>
#
# > Code Result: It appears that there are no missing values in the df_encoded dataframe. The dataframe was sucessfully merged.
#
#
# How do you know? We only see the first and last five rows above.
# </div>

# %% [markdown]
# Note To Reviewer:
# I fixed this issue in the cell above.

# %% [markdown]
# <div class="alert alert-danger" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b>   Reviewer's comment 2 </b>
#
# Please don't drop so many rows. Even if a row has a missing value in one column, it still has important information in other columns.
#
# </div>

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <h2>   Reviewer's comment 2 </h2>
#
# Good! However, they may appear after you save the missing values.
# </div>

# %% [markdown]
# <div class="alert alert-warning" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <h2>   Reviewer's comment 2 </h2>
#
# You don't need two dataframes, do you? Isn't it easier to work with one dataframe?
# </div>

# %% [markdown]
# Note to Reviewer:
# I decided to get rid of these two dataframes, so these comments may be irrelevant for this review.
# Thank you for the suggestions.

# %%
#Use the duplicated() and sum() methods in order to check for duplicate values in the final_df dataframe. 
df_encoded.duplicated().sum()
# Out:
# 110

# %% [markdown]
# Code Result:
# It appears that there are 110 duplicate values noted in the df_encoded dataframe.  These duplicate values will be dropped.

# %%
#Use the drop_duplicates() method in order to drop duplicate values in the not_encoded_df dataframe. 
df_encoded.drop_duplicates(inplace=True) 

#Use the duplicated() and sum() methods in order to double check for duplicate values in the final_df dataframe.
df_encoded.duplicated().sum()
# Out:
# 0

# %% [markdown]
# Code Result:
# There are no longer any missing values noted in the df_encoded dataframe.

# %% [markdown]
# <div class="alert alert-danger" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Reviewer's comment </b>
#
# `get_dummies` increases data size as it converts categorical features into multiple binary columns, which makes the training process more complex and time-consuming. Additionally, such encoding loses the relationships between categories if it exists. So we should not use it with the tree-based models, since it significantly increases the number of features and computational cost. Instead, try to use  `OneHotEncoder()`  from sklearn or `OrdinalEncoder()`. What is more, `OneHotEncoder()` handles situations where test subset has features that were not available during training. [Difference between OneHotEncoder and get_dummies](https://pythonsimplified.com/difference-between-onehotencoder-and-get_dummies/).
#
# </div>
# <div class="alert alert-warning" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Reviewer's comment </b>
#
#
#
# - For boosting algorithms, we can rely on internal encoders that usually perform even better than external ones. For `CatBoost`, this is controlled by the `cat_features` parameter. For `LightGBM`, you can convert categorical features to the category type, allowing the model to handle them automatically.
#
#
#
# - Please note that `OrdinalEncoder()` or `LabelEncoder()` should not be used with linear models if there's no ordinal relationship. [How and When to Use Ordinal Encoder](https://leochoi146.medium.com/how-and-when-to-use-ordinal-encoder-d8b0ef90c28c).</div>

# %% [markdown]
# ## Model training

# %%
#Create seed for the random state.
seed = 12345 

#Use the np.random.RandomState() method in order to create a random state for the models.
state = np.random.RandomState(seed)

# %%
#Create a function in order to calculate the rmse for each model.
def rmse(y_true, y_pred):
    return np.sqrt(mean_squared_error(y_true, y_pred)) 

#Use the make_scorer() function to create a scorer for the GridSearch and RandomizedSearch models using the rmse
#metric.  Set the greater_is_better parameter to False.
rmse_scorer = make_scorer(rmse, greater_is_better=False)

# %%
#Set the price column as the target.
X = df_encoded.drop(['price'], axis=1)
y = df_encoded['price']
#Use the train_test_split method to split the features and the target datasets into training
#and test sets using a 70:30 ratio.
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=state)

# %%
#Use StandardScaler() to scale the numerical features in the features test and training sets.
scaler = StandardScaler() 
X_train[numerical_features] = scaler.fit_transform(X_train[numerical_features])
X_test[numerical_features] = scaler.transform(X_test[numerical_features])

# %% [markdown]
# <div class="alert alert-danger" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Reviewer's comment </b>
#
# Why did you decide to drop columns such as brand, model, vehicle_type, repaired and fuel type?
# </div>

# %% [markdown]
# #### Note to Reviewer:
# This is my correction of my code.

# %%
#Use the np.mean() method in order to get the mean for the training set of the target dataset.
y_mean_pred = np.mean(y_train)
#Use the rmse() function to calculate the rmse of between the training set of the target dataset and 
#the product of the mean for the training set of the target dataset and the length the of the
#training set of target datset. This will be the baseline rmse for the dataset.
baseline_rmse = rmse(y_train, [y_mean_pred] * len(y_train))

# %%
#Use np.mean() in order order to get the mean value of the price column of the df_cleaned dataframe.
price_mean = np.mean(df_cleaned['price']) 

#Create a function that calculates the RMSE error percentage.
def rmse_percentage(model_rmse, y_mean):
    percentage = (model_rmse / y_mean) * 100
    return percentage

#Print the Baseline RMSE.
print(f"Baseline RMSE (Training Set): {baseline_rmse:.2f}")
#Print Basline RMSE error percentage.
print(f"Baseline RMSE Error Percentage (Training Set): {rmse_percentage(baseline_rmse, price_mean):.2f} %")
# Out:
# Baseline RMSE (Training Set): 4460.21
# Baseline RMSE Error Percentage (Training Set): 84.40 %

# %% [markdown]
# <div class="alert alert-danger" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Reviewer's comment </b>
#
# Please don't use test subset until you move on to the final test. We first train and tune all models, then we identify the best model (or two models if their metrics are similar), and then we run the final test using the test subset. So we do it once in the project.
#
# </div>

# %% [markdown]
# #### Linear Regression Model

# %%
#Create the a Linear Regression model using the LinearRegression() class.
lr = LinearRegression()

#Use the time.time() function in order to calculate the start time for the model's
#training process.
lr_st = time.time()
#Use the fit() method in order to train the model with the training sets of the 
#scaled features dataset and target datasets.
lr.fit(X_train, y_train) 
#Use the time.time() function in order to calculate the end time for the model's
#training process.
lr_et = time.time()
#Calculate the model's total training time by subtracting the end time from the start time.
lr_time = lr_et - lr_st 

#Print the model's total training time.
print(f"Linear Regression Model Training Time {lr_time:.2f} seconds")
# Out:
# Linear Regression Model Training Time 3.54 seconds

# %%
#Use the time.time() function in order to calculate the start time for the model's
#prediction process.
lr_pred_st = time.time()
#Use the predict() method in order to make a prediciton based on the training set of the scaled
#features dataset using the Linear Regeression model.
lr_predicted = lr.predict(X_train) 
#Use the time.time() function in order to calculate the end time for the model's
#prediction process.
lr_pred_et = time.time()
#Calculate the model's total prediction time by subtracting the end time from the start time.
lr_pred_time = lr_pred_et = lr_pred_st

#Print the model's total training time.
print(f"Linear Regression Model Prediction Time {lr_pred_time:.2f} seconds")

#Use the rmse() method in order to print the rmse between the training set of the target dataset
#and the model's predicted values.
lr_rmse = rmse(y_train, lr_predicted) 
#Print the model's RMSE.
print(f"Linear Regression Model RMSE {lr_rmse:.2f}")
#Print the model's RMSE Serror percentage.
print(f"Linear Regressor RMSE Error Percentage: {rmse_percentage(lr_rmse, price_mean):.2f} %")
# Out:
# Linear Regression Model Prediction Time 1743724895.59 seconds
# Linear Regression Model RMSE 2128.26
# Linear Regressor RMSE Error Percentage: 40.27 %

# %% [markdown]
# #### SGD Linear Regression Model

# %%
#Create a class for a Stochastic Gradient Descent Linear Regression model.
class SGDLinearRegression:
    #Initialize the self paramter and the: step_size, epochs, batch_size, and reg_weight hyperparameters
    def __init__(self, step_size, epochs, batch_size, reg_weight):
        self.step_size = step_size
        self.epochs = epochs
        self.batch_size = batch_size
        self.reg_weight = reg_weight
    
    #Create the fit() function to train the model.
    def fit(self, train_features, train_target):
        X = np.concatenate(
            (np.ones((train_features.shape[0], 1)), train_features), axis=1
        )
        y = train_target
        w = np.zeros(X.shape[1])
        
        #Create a for loop to calculate the number of epochs and batches need for the model's
        # weigh calculation.
        for _ in range(self.epochs):
            batches_count = X.shape[0] // self.batch_size
            for i in range(batches_count):
                begin = i * self.batch_size
                end = (i + 1) * self.batch_size
                X_batch = X[begin:end, :]
                y_batch = y[begin:end]
                
                #Calculate the gradient.
                gradient = (
                    2
                    * X_batch.T.dot(X_batch.dot(w) - y_batch)
                    / X_batch.shape[0]
                )
								
                #Calculate the regularization weight.
                reg = 2 * w.copy()
                reg[0] = 0
                #Multiply the gradient by the regularization weight,
                gradient +=  self.reg_weight * reg
                #Subtract the product of the step size the gradient(with regularization)
                #from the weight.
                w -= self.step_size * gradient
                
        #Create a variable for the calculated weights without bias.
        self.w = w[1:]
        #Create a variable for the calculated weights with bias.
        self.w0 = w[0]
    
    #Create the predict() method in order to calculate predicted values using the model.
    def predict(self, test_features):
        return test_features.dot(self.w) + self.w0

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <h2>   Reviewer's comment </h2>
#
# Nice code! </div>

# %%
#Use the SGDLinearRegression() method in order to create an SGD Linear Regression model with 
#default hyperparameters.  The model's hyperparameters will be tuned using GridSearch.
sgd = SGDLinearRegression(step_size=0.01, epochs=10, batch_size=100, reg_weight=0.0)

# %%
#Create a parameter grid for the SGD Linear Regression model.
sgd_param_grid = {
    'step_size': [0.001, 0.05],
    'epochs': [50, 100],
    'batch_size': [50, 100],
    'reg_weight': [0.001, 0.1]
}

# %%
#Create a class named SGDLinearRegressionWrapped that contains the wrapped version of the SGDLinearRegression model
#in order to make the model more compatible with GridSearch.
class SGDLinearRegressionWrapped(BaseEstimator, RegressorMixin):
    def __init__(self, step_size=0.01, epochs=10, batch_size=100, reg_weight=0.0):
        self.step_size = step_size 
        self.epochs = epochs 
        self.batch_size = batch_size 
        self.reg_weight = reg_weight 
        self.model = SGDLinearRegression(step_size, epochs, batch_size, reg_weight) 
        
    def fit(self, X, y):
        self.model.fit(X, y) 
        
    def predict(self, X):
        self.model.predict(X)

# %%
#Create wrapped model for the SGD Linear Regression model for GridSearch.
sgd_wrapped = SGDLinearRegressionWrapped()

# %%
#Create a GridSearch model for the SGD Linear Regression model.
sgd_gsearch = GridSearchCV(estimator=sgd_wrapped,
                           param_grid=sgd_param_grid,
                           cv=5,
                           n_jobs=-1,
                           scoring=rmse_scorer) 
#Use the fit() method in order to train the GridSearch model with the training sets of the 
#scaled features dataset and target datasets.
sgd_gsearch.fit(X_train, y_train)
# Out:
# c:\Users\HP\anaconda3\Lib\site-packages\sklearn\model_selection\_search.py:1108: UserWarning: One or more of the test scores are non-finite: [nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan]
#   warnings.warn(
# GridSearchCV(cv=5, estimator=SGDLinearRegressionWrapped(), n_jobs=-1,
#              param_grid={'batch_size': [50, 100], 'epochs': [50, 100],
#                          'reg_weight': [0.001, 0.1],
#                          'step_size': [0.001, 0.05]},
#              scoring=make_scorer(rmse, greater_is_better=False, response_method='predict'))

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <h2>   Reviewer's comment </h2>
#
# You have successfully implemented hyperparameters tuning, well done!
# </div>
# <div class="alert alert-warning" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <h2>   Reviewer's comment </h2>
#
# The issue should be fixed when you use the correct encoder.</div>

# %%
#Use the best_score_ method in order to get the best score for the model.
sgd_bscore = sgd_gsearch.best_score_
#Use the best_params_ method in order to get the best score for the model.
sgd_bparams = sgd_gsearch.best_params_  

#Print the SGD Linear Regression Model's Best Score.
print(f"SGD Linear Regression Best Score: {sgd_bscore:.2f}")
#Print the SGD Linear Regression Model's Best Hyperparameters.
print(f"SGD Linear Regression Model Best Hyperparameters: \n{sgd_bparams}")
# Out:
# SGD Linear Regression Best Score: nan
# SGD Linear Regression Model Best Hyperparameters:
# {'batch_size': 50, 'epochs': 50, 'reg_weight': 0.001, 'step_size': 0.001}

# %%
#Create an SGD Linear Regression model using the SGDLinearRegression() class with tuned hyperparameters.
sgd = SGDLinearRegression(batch_size=50, epochs=50, reg_weight=0.001, step_size=0.001) 

#Use the time.time() function in order to calculate the start time for the model's
#training process.
sgd_st = time.time()
#Use the fit() method in order to train the model with the training sets of the 
#scaled features dataset and target datasets. 
sgd.fit(X_train, y_train) 
#Use the time.time() function in order to calculate the end time for the model's
#training process.
sgd_et = time.time()
#Calculate the model's total training time by subtracting the end time from the start time. 
sgd_time = sgd_et - sgd_st

#Print the model's total training time.
print(f"SGD Linear Regression Training Time {sgd_time:.2f} seconds")
# Out:
# SGD Linear Regression Training Time 23.10 seconds

# %%
#Use the time.time() function in order to calculate the start time for the model's
#prediction process. 
sgd_pred_st = time.time()
#Use the predict() method in order to make a prediciton based on the training set of the scaled
#features dataset using the SGD Linear Regeression model. 
sgd_predicted = sgd.predict(X_train) 
#Use the time.time() function in order to calculate the end time for the model's
#prediction process.
sgd_pred_et = time.time() 
#Calculate the model's total prediction time by subtracting the end time from the start time. 
sgd_pred_time = sgd_pred_et - sgd_pred_st

#Print the model's total training time.
print(f"SGD Prediction Time {sgd_pred_time:.2f} seconds")

#Use the rmse() method in order to print the rmse between the training set of the target dataset
#and the model's predicted values. 
sgd_rmse = rmse(y_train, sgd_predicted) 
#Print the model's RMSE.
print(f"SGD Linear Regression RMSE: {sgd_rmse:.2f}")
#Print the model's RMSE Serror percentage.
print(f"SGD Linear Regression RMSE Error Percentage: {rmse_percentage(sgd_rmse, price_mean):.2f} %")
# Out:
# SGD Prediction Time 0.11 seconds
# SGD Linear Regression RMSE: 2226.73
# SGD Linear Regression RMSE Error Percentage: 42.14 %

# %% [markdown]
# <div class="alert alert-danger" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b>   Reviewer's comment </b>
#
# Here and further, please don't use test subset. Calculate RMSE on training data please.
# </div>
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <h2>   Reviewer's comment 2 </h2>
#
# Good.
# </div>

# %% [markdown]
# #### Decision Tree Regressor Model

# %%
#Use DecisionTreeRegressor() to create a Decision Tree Regressor model.
dt_regressor = DecisionTreeRegressor(random_state=state)

# %%
#Create a parameter grid for the Decision Tree Regressor's Gridsearch Model.
dtr_param_grid = {
    'max_depth': [None, 10, 15],
    'min_samples_split': [2, 5],
    'min_samples_leaf': [1, 2],
    'max_features': ['auto', 'sqrt']
} 

#Create a GridSearch Model for the Decision Tree Regressor model.
dtr_gsearch = GridSearchCV(estimator=dt_regressor,
                           param_grid=dtr_param_grid, 
                           cv=5, n_jobs=-1, 
                           scoring=rmse_scorer)

#Use the fit() method in order to train the GridSearch model with the training sets of the 
#scaled features dataset and target datasets.
dtr_gsearch.fit(X_train, y_train)
# Out:
# c:\Users\HP\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py:528: FitFailedWarning:
# 60 fits failed out of a total of 120.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 45 fits failed with the following error:
# Traceback (most recent call last):
#   File "c:\Users\HP\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 866, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "c:\Users\HP\anaconda3\Lib\site-packages\sklearn\base.py", line 1382, in wrapper
#     estimator._validate_params()
#   File "c:\Users\HP\anaconda3\Lib\site-packages\sklearn\base.py", line 436, in _validate_params
#     validate_parameter_constraints(
#   File "c:\Users\HP\anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py", line 98, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'max_features' parameter of DecisionTreeRegressor must be an int in the range [1, inf), a float in the range (0.0, 1.0], a str among {'sqrt', 'log2'} or None. Got 'auto' instead.
#
# --------------------------------------------------------------------------------
# 15 fits failed with the following error:
# Traceback (most recent call last):
#   File "c:\Users\HP\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 866, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "c:\Users\HP\anaconda3\Lib\site-packages\sklearn\base.py", line 1382, in wrapper
#     estimator._validate_params()
#   File "c:\Users\HP\anaconda3\Lib\site-packages\sklearn\base.py", line 436, in _validate_params
#     validate_parameter_constraints(
#   File "c:\Users\HP\anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py", line 98, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'max_features' parameter of DecisionTreeRegressor must be an int in the range [1, inf), a float in the range (0.0, 1.0], a str among {'log2', 'sqrt'} or None. Got 'auto' instead.
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# c:\Users\HP\anaconda3\Lib\site-packages\sklearn\model_selection\_search.py:1108: UserWarning: One or more of the test scores are non-finite: [           nan            nan            nan            nan
#  -2498.85096008 -2322.73211197 -2448.37749143 -2270.1322515
#             nan            nan            nan            nan
#  -3540.30772893 -3513.15243752 -3574.22412187 -3619.85349954
#             nan            nan            nan            nan
#  -2896.06095317 -2811.89342745 -3078.45548905 -3088.35443952]
#   warnings.warn(
# GridSearchCV(cv=5,
#              estimator=DecisionTreeRegressor(random_state=RandomState(MT19937) at 0x15DA3F4A340),
#              n_jobs=-1,
#              param_grid={'max_depth': [None, 10, 15],
#                          'max_features': ['auto', 'sqrt'],
#                          'min_samples_leaf': [1, 2],
#                          'min_samples_split': [2, 5]},
#              scoring=make_scorer(rmse, greater_is_better=False, response_method='predict'))

# %%
#Print the Decision Tree Regressor Model's Best Score.
print(f"Descision Tree Regressor Best Score:{dtr_gsearch.best_score_:.2f}") 
#Print the Decision Tree Regressor Model's Best Hyperparameters.
print(f"Decision Tree Regressor Best HyperParameters: \n{dtr_gsearch.best_params_}")
# Out:
# Descision Tree Regressor Best Score:-2270.13
# Decision Tree Regressor Best HyperParameters:
# {'max_depth': None, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 5}

# %%
#Recreate the Decision Tree Regressor Model with tuned hyperparameters.
dtr = DecisionTreeRegressor(max_depth=None, 
                            max_features='sqrt',
                            min_samples_leaf=2,
                            min_samples_split=5,
                            random_state=state)

#Use the time.time() function in order to calculate the start time for the model's
#training process.
dt_st = time.time()

#Use the fit() method in order to train the model with the training sets of the 
#scaled features dataset and target datasets. 
dtr.fit(X_train, y_train) 

#Use the time.time() function in order to calculate the end time for the model's
#training process.
dt_et = time.time() 

#Calculate the model's total training time by subtracting the end time from the start time. 
dt_training_time = dt_et - dt_st

#Print the model's total training time.
print(f"Decision Tree Regressor Training Time {dt_training_time:.2f} seconds")
# Out:
# Decision Tree Regressor Training Time 0.52 seconds

# %%
#Use the time.time() function in order to calculate the start time for the model's
#prediction process. 
dt_pred_st = time.time()

#Use the predict() method in order to make a prediciton based on the test set of the scaled
#features dataset using the  model. 
dtr_predicted = dtr.predict(X_train) 

#Use the time.time() function in order to calculate the end time for the model's
#prediction process.
dt_pred_et = time.time() 

#Calculate the model's total prediction time by subtracting the end time from the start time. 
dt_pred_time = dt_pred_et = dt_pred_st 
#Print the model's total prediction time.
print(f"Decision Tree Regressor Prediction Time: {dt_pred_time:.2f} seconds")

#Use the rmse() method in order to print the rmse between the training set of the target dataset
#and the model's predicted values. 
dtr_rmse = rmse(y_train, dtr_predicted)
#Print the model's RMSE.
print(f"Decision Tree Regressor RMSE: {dtr_rmse:.2f}")
#Print the model's RMSE error percentage.
print(f"Decision Tree Regressor Error Percentage: {rmse_percentage(dtr_rmse, price_mean):.2f} %")
# Out:
# Decision Tree Regressor Prediction Time: 1743725092.55 seconds
# Decision Tree Regressor RMSE: 2163.39
# Decision Tree Regressor Error Percentage: 40.94 %

# %% [markdown]
# <div class="alert alert-danger" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b>   Reviewer's comment </b>
#
# Same issue. </div>

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <h2>   Reviewer's comment 3 </h2>
#
# Good result!
#
# </div>

# %% [markdown]
# #### Random Forest Regressor Model

# %%
#Use RandomForestRegressor() to create a Random Forest Regressor Model.
rfr = RandomForestRegressor(random_state=state)

# %%
#Create a paramter grid for the Random Forest Regressor Model's GridSearch.
rfr_param_grid = {
    'n_estimators': [50, 100],
    'max_depth': [None, 10, 20],
    'min_samples_split': [2, 5],
    'min_samples_leaf': [1, 2],
    'max_features': ['sqrt']
}

# %%
#Create a GridSearch Model for the Random Forest Regressor model.
rfr_gsearch = GridSearchCV(estimator=rfr,
                           param_grid=rfr_param_grid,
                           cv=3,
                           n_jobs=-1,
                           verbose=2,
                           scoring=rmse_scorer) 

#Use the fit() method in order to train the GridSearch model with the training sets of the 
#scaled features dataset and target datasets.
rfr_gsearch.fit(X_train, y_train)
# Out:
# Fitting 3 folds for each of 24 candidates, totalling 72 fits
# GridSearchCV(cv=3,
#              estimator=RandomForestRegressor(random_state=RandomState(MT19937) at 0x15DA3F4A340),
#              n_jobs=-1,
#              param_grid={'max_depth': [None, 10, 20], 'max_features': ['sqrt'],
#                          'min_samples_leaf': [1, 2],
#                          'min_samples_split': [2, 5],
#                          'n_estimators': [50, 100]},
#              scoring=make_scorer(rmse, greater_is_better=False, response_method='predict'),
#              verbose=2)

# %%
#Use the best_score_ method in order to get the best score for the model. 
print(f"Random Forest Regressor Model Best Score: {rfr_gsearch.best_score_:.2f}") 
#Use the best_params_ method in order to get the best score for the model.
print(f"Random Forest Regressor Model Best Hyperparameters: \n{rfr_gsearch.best_params_}")
# Out:
# Random Forest Regressor Model Best Score: -1586.58
# Random Forest Regressor Model Best Hyperparameters:
# {'max_depth': None, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 100}

# %%
#Recreate the Random Forest Regressor Model with tuned hyperparameters.
rfr = RandomForestRegressor(max_depth=None,
                            max_features='sqrt',
                            min_samples_leaf=1,
                            min_samples_split=2,
                            n_estimators=100, 
                            random_state=state) 

#Use the time.time() function in order to calculate the start time for the model's
#training process.
rf_st = time.time()

#Use the fit() method in order to train the model with the training sets of the 
#scaled features dataset and target datasets. 
rfr.fit(X_train, y_train) 

#Use the time.time() function in order to calculate the end time for the model's
#training process.
rf_et = time.time() 
#Calculate the model's total training time by subtracting the end time from the start time. 
rf_time = rf_et - rf_st

#Print the model's total training time.
print(f"Random Forest Regressor Training Time: {rf_time:.2f} seconds")
# Out:
# Random Forest Regressor Training Time: 42.63 seconds

# %%
#Use the time.time() function in order to calculate the start time for the model's
#prediction process. 
rf_pred_st = time.time()

#Use the predict() method in order to make a prediciton based on the training set of the scaled
#features dataset using the  model. 
rfr_predicted = rfr.predict(X_train) 

#Use the time.time() function in order to calculate the end time for the model's
#prediction process.
rf_pred_et = time.time()
#Calculate the model's total prediction time by subtracting the end time from the start time. 
rf_pred_time = rf_pred_et - rf_pred_st

#Print the model's total prediction time.
print(f"Random Forest Regressor Prediction Time: {rf_pred_time:.2f} seconds")

#Use the rmse() method in order to print the rmse between the training set of the target dataset
#and the model's predicted values. 
rfr_rmse = rmse(y_train, rfr_predicted)
#Print the model's RMSE.
print(f"Random Forest Regressor RMSE: {rfr_rmse:.2f}")
#Print the model's RMSE Serror percentage.
print(f"Random Forest Regressor RMSE Error Percentage: {rmse_percentage(rfr_rmse, price_mean):.2f} %")
# Out:
# Random Forest Regressor Prediction Time: 3.96 seconds
# Random Forest Regressor RMSE: 597.36
# Random Forest Regressor RMSE Error Percentage: 11.30 %

# %% [markdown]
# <div class="alert alert-danger" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b>   Reviewer's comment </b>
#
# Same issue. </div>

# %% [markdown]
# #### XG Boost Regressor Model

# %%
#Use XGBRegressor() in order to create an XG Boost Regressor Model.
xgbr = XGBRegressor(random_state=state)

# %%
#Create a paramter grid for the  Regressor Model's GridSearch.
xgbr_param_grid = {
    'n_estimators': [100, 200],  
    'learning_rate': [0.1],  
    'max_depth': [3, 4],  
}

# %%
#Create a GridSearch Model for the XG Boost Regressor model.
xgbr_gsearch = GridSearchCV(estimator=xgbr, 
                           param_grid=xgbr_param_grid, 
                           cv=3,
                           n_jobs=-1,
                           verbose=2,
                           scoring=rmse_scorer) 

#Use the fit() method in order to train the GridSearch model with the training sets of the 
#scaled features dataset and target datasets.
xgbr_gsearch.fit(X_train, y_train)
# Out:
# Fitting 3 folds for each of 4 candidates, totalling 12 fits
# GridSearchCV(cv=3,
#              estimator=XGBRegressor(base_score=None, booster=None,
#                                     callbacks=None, colsample_bylevel=None,
#                                     colsample_bynode=None,
#                                     colsample_bytree=None, device=None,
#                                     early_stopping_rounds=None,
#                                     enable_categorical=False, eval_metric=None,
#                                     feature_types=None, gamma=None,
#                                     grow_policy=None, importance_type=None,
#                                     interaction_constraints=None,
#                                     learning_rate=None, m...
#                                     max_depth=None, max_leaves=None,
#                                     min_child_weight=None, missing=nan,
#                                     monotone_constraints=None,
#                                     multi_strategy=None, n_estimators=None,
#                                     n_jobs=None, num_parallel_tree=None,
#                                     random_state=746142862, ...),
#              n_jobs=-1,
#              param_grid={'learning_rate': [0.1], 'max_depth': [3, 4],
#                          'n_estimators': [100, 200]},
#              scoring=make_scorer(rmse, greater_is_better=False, response_method='predict'),
#              verbose=2)

# %%
#Use the best_score_ method in order to get the best score for the model. 
print(f"XG Boost Regressor Best Score: {xgbr_gsearch.best_score_:.2f}")
#Use the best_params_ method in order to get the best score for the model.
print(f"XG Boost Regressor Best Hyperparameters: {xgbr_gsearch.best_params_}")
# Out:
# XG Boost Regressor Best Score: -1550.85
# XG Boost Regressor Best Hyperparameters: {'learning_rate': 0.1, 'max_depth': 4, 'n_estimators': 200}

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <h2>   Reviewer's comment 3 </h2>
#
# Well done! You can display positive values, by the way.
# </div>

# %%
#Recreate the XG Boost Regressor Model with tuned hyperparameters.
xgb = XGBRegressor(learning_rate=0.1, 
                       max_depth=4, 
                       n_estimators=200, 
                       random_state=state) 

 #Use the time.time() function in order to calculate the start time for the model's
#training process.                     
xgb_st = time.time() 

#Use the fit() method in order to train the model with the training sets of the 
#scaled features dataset and target datasets. 
xgb.fit(X_train, y_train) 

#Use the time.time() function in order to calculate the end time for the model's
#training process.
xgb_et = time.time() 

#Calculate the model's total training time by subtracting the end time from the start time. 
xgb_time = xgb_et - xgb_st 

#Print the model's total training time.
print(f"XG Boost Regressor Training Time {xgb_time:.2f} seconds")
# Out:
# XG Boost Regressor Training Time 5.34 seconds

# %%
#Use the time.time() function in order to calculate the start time for the model's
#prediction process. 
xgb_pred_st = time.time()

#Use the predict() method in order to make a prediciton based on the training set of the scaled
#features dataset using the  model. 
xgb_predicted = xgb.predict(X_train) 

#Use the time.time() function in order to calculate the end time for the model's
#prediction process.
xgb_pred_et = time.time()
#Calculate the model's total prediction time by subtracting the end time from the start time. 
xgb_pred_time = xgb_pred_et - xgb_pred_st 
#Print the model's total prediction time.
print (f"XG Boost Regressor Prediction Time: {xgb_pred_time:.2f} seconds")

#Use the rmse() method in order to print the rmse between the training set of the target dataset
#and the model's predicted values. 
xgb_rmse = rmse(y_train, xgb_predicted) 
#Print the model's RMSE.
print(f"XG Boost Regressor RMSE: {xgb_rmse:.2f}")
#Print the model's RMSE Serror percentage.
print(f"XG Boost Regressor RMSE Error Percentage: {rmse_percentage(xgb_rmse, price_mean):.2f} %")
# Out:
# XG Boost Regressor Prediction Time: 0.67 seconds
# XG Boost Regressor RMSE: 1495.96
# XG Boost Regressor RMSE Error Percentage: 28.31 %

# %% [markdown]
# <div class="alert alert-danger" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b>   Reviewer's comment </b>
#
# Same issue. </div>

# %% [markdown]
# #### CatBoost Regressor Model

# %% [markdown]
# #### Note to Reviewer:
# I tried to use the built in encoding features for the CatBoostRegressor Model to encode the categorical features, but my code
# kept returning an error. So, I decided to just use OneHotEncoder() in order to encode the categorical features

# %%
#Use CatBoostRegressor() to create a CatBoost Regressor Model.
cbr = CatBoostRegressor(random_seed=state, verbose=0)

# %%
#Create a paramter grid for the CatBoost Regressor Model's GridSearch.
cb_param_grid = {
    'depth': [4, 6],
    'learning_rate': [0.1],
    'iterations': [100, 200],
    'random_seed': [42],
    'metric_period': [50, 100]
}

# %%
#Create a GridSearch Model for the CatBoost Regressor model.
cbr_gsearch = GridSearchCV(estimator=cbr, 
                           param_grid=cb_param_grid, 
                           cv=3, 
                           n_jobs=-1, 
                           scoring=rmse_scorer)

#Use the fit() method in order to train the GridSearch model with the training sets of the 
#scaled features dataset and target datasets.
cbr_gsearch.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=3,
#              estimator=<catboost.core.CatBoostRegressor object at 0x0000015DF3FF7810>,
#              n_jobs=-1,
#              param_grid={'depth': [4, 6], 'iterations': [100, 200],
#                          'learning_rate': [0.1], 'metric_period': [50, 100],
#                          'random_seed': [42]},
#              scoring=make_scorer(rmse, greater_is_better=False, response_method='predict'))

# %%
#Use the best_score_ method in order to get the best score for the model. 
print(f"CatBoostRegressor Best Score: {cbr_gsearch.best_score_:.2f}") 
#Use the best_params_ method in order to get the best score for the model.
print(f"CatBoostRegressor Best Hyperparameters: \n{cbr_gsearch.best_params_}")
# Out:
# CatBoostRegressor Best Score: -1533.36
# CatBoostRegressor Best Hyperparameters:
# {'depth': 6, 'iterations': 200, 'learning_rate': 0.1, 'metric_period': 50, 'random_seed': 42}

# %%
#Recreate the CatBoost Regressor Model with tuned hyperparameters.
cbr = CatBoostRegressor(depth=6, 
                        iterations=200, 
                        learning_rate=0.1, 
                        metric_period=50,
                        random_seed=seed) 

#Use the time.time() function in order to calculate the start time for the model's
#training process.
cbr_st = time.time() 

#Use the fit() method in order to train the model with the training sets of the 
#scaled features dataset and target datasets. 
cbr.fit(X_train, y_train) 

#Use the time.time() function in order to calculate the end time for the model's
#training process.
cbr_et = time.time() 

#Calculate the model's total training time by subtracting the end time from the start time. 
cbr_time = cbr_et - cbr_st 

#Print the model's total training time.
print(f"CatBoost Regressor Training Time: {cbr_time:.2f} Seconds")
# Out:
# 0:	learn: 4155.1898617	total: 20.9ms	remaining: 4.17s
# 50:	learn: 1705.9398537	total: 828ms	remaining: 2.42s
# 100:	learn: 1584.3279771	total: 1.55s	remaining: 1.52s
# 150:	learn: 1527.7911038	total: 2.38s	remaining: 774ms
# 199:	learn: 1491.5753800	total: 3.15s	remaining: 0us
# CatBoost Regressor Training Time: 3.85 Seconds

# %%
#Use the time.time() function in order to calculate the start time for the model's
#prediction process. 
cbr_pred_st = time.time()

#Use the predict() method in order to make a prediciton based on the training set of the scaled
#features dataset using the  model. 
cbr_predicted = cbr.predict(X_train) 

#Use the time.time() function in order to calculate the end time for the model's
#prediction process.
cbr_pred_et = time.time()
#Calculate the model's total prediction time by subtracting the end time from the start time.
cbr_pred_time = cbr_pred_et - cbr_pred_st
#Print the model's total prediction time.
print(f"CatBoost Regressor Prediction Time: {cbr_pred_time:.2f}") 

#Use the rmse() method in order to print the rmse between the training set of the target dataset
#and the model's predicted values. 
cbr_rmse = rmse(y_train, cbr_predicted)
#Print the model's RMSE.
print(f"CatBoost Regressor Model RMSE {cbr_rmse:.2f}")
#Print the model's RMSE Serror percentage.
print(f"CatBoost Regressor RMSE Error Percentage: {rmse_percentage(cbr_rmse, price_mean):.2f} %")
# Out:
# CatBoost Regressor Prediction Time: 0.10
# CatBoost Regressor Model RMSE 1491.58
# CatBoost Regressor RMSE Error Percentage: 28.23 %

# %% [markdown]
# <div class="alert alert-danger" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b>   Reviewer's comment </b>
#
# Same issue. </div>

# %% [markdown]
# #### LightGBM Model

# %%
#Use LGMRegressor() to create a Light GBM Regressor Model.
lgb = LGBMRegressor(random_state=state)

# %%
#Create a paramter grid for the Light GBM Regressor Model's GridSearch.
lgb_param_grid = {
    'num_leaves': [31],
    'learning_rate': [0.1],
    'n_estimators': [100, 200]
}

# %%
#Create a GridSearch Model for the  model.
lgb_gsearch = GridSearchCV(estimator=lgb, 
                           param_grid=lgb_param_grid, 
                           scoring=rmse_scorer,
                           cv=3,
                           verbose=2, 
                           n_jobs=-1)

#Use the fit() method in order to train the GridSearch model with the training sets of the 
#scaled features dataset and target datasets.
lgb_gsearch.fit(X_train, y_train)
# Out:
# Fitting 3 folds for each of 2 candidates, totalling 6 fits
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.005431 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 912
# [LightGBM] [Info] Number of data points in the train set: 54793, number of used features: 268
# [LightGBM] [Info] Start training from score 5291.050098
# GridSearchCV(cv=3,
#              estimator=LGBMRegressor(random_state=RandomState(MT19937) at 0x15DA3F4A340),
#              n_jobs=-1,
#              param_grid={'learning_rate': [0.1], 'n_estimators': [100, 200],
#                          'num_leaves': [31]},
#              scoring=make_scorer(rmse, greater_is_better=False, response_method='predict'),
#              verbose=2)

# %%
#Use the best_score_ method in order to get the best score for the model. 
print(f"LightGBM Model Best Score: {lgb_gsearch.best_score_:.2f}")
#Use the best_params_ method in order to get the best score for the model.
print(f"LightGBM Best Hyperparameters: {lgb_gsearch.best_params_}")
# Out:
# LightGBM Model Best Score: -1464.83
# LightGBM Best Hyperparameters: {'learning_rate': 0.1, 'n_estimators': 200, 'num_leaves': 31}

# %%
#Recreate the Regressor Model with tuned hyperparameters.
lgb = LGBMRegressor(learning_rate=0.1,
                        n_estimators=200,
                        num_leaves=31, 
                        random_state=state) 

#Use the time.time() function in order to calculate the start time for the model's
#training process.
lgb_st = time.time()

#Use the fit() method in order to train the model with the training sets of the 
#scaled features dataset and target datasets. 
lgb.fit(X_train, y_train) 

#Use the time.time() function in order to calculate the end time for the model's
#training process.
lgb_et = time.time() 
#Calculate the model's total training time by subtracting the end time from the start time.
lgb_time = lgb_et - lgb_st

#Print the model's total training time.
print(f"Light GBM Regressor Model Training Time: {lgb_time:.2f} seconds")
# Out:
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.002881 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 912
# [LightGBM] [Info] Number of data points in the train set: 54793, number of used features: 268
# [LightGBM] [Info] Start training from score 5291.050098
# Light GBM Regressor Model Training Time: 1.28 seconds

# %%
#Use the time.time() function in order to calculate the start time for the model's
#prediction process. 
lgb_pred_st = time.time()

#Use the predict() method in order to make a prediction based on the training set of the scaled
#features dataset using the  model. 
lgb_predicted = lgb.predict(X_train) 

#Use the time.time() function in order to calculate the end time for the model's
#prediction process.
lgb_pred_et = time.time()

#Calculate the model's total prediction time by subtracting the end time from the start time.
lgb_pred_time = lgb_pred_et - lgb_pred_st
#Print the model's total prediction time.
print(f"Light GBM Regressor Prediction Time: {lgb_pred_time:.2f} seconds") 

#Use the rmse() method in order to print the rmse between the training set of the target dataset
#and the model's predicted values. 
lgb_rmse = rmse(y_train, lgb_predicted)
#Print the model's RMSE.
print(f"Light GBM Regressor RMSE: {lgb_rmse:.2f}")
#Print the model's RMSE Serror percentage.
print(f"Light GBM Regressor RMSE Error Percentage: {rmse_percentage(lgb_rmse, price_mean):.2f} %")
# Out:
# Light GBM Regressor Prediction Time: 0.77 seconds
# Light GBM Regressor RMSE: 1356.62
# Light GBM Regressor RMSE Error Percentage: 25.67 %

# %% [markdown]
# <div class="alert alert-danger" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b>   Reviewer's comment </b>
#
# Same issue. </div>

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <h2>   Reviewer's comment 3 </h2>
#
# Very good job!
# </div>

# %% [markdown]
# #### Model analysis

# %% [markdown]
# Baseline RMSE (Training Set): 4460.21
# Baseline RMSE Error Percentage (Training Set): 84.40 %
#
# Models Ranked Based on RMSE:
#
# 1) Random Forest Regressor Model
# Random Forest Regressor RMSE: 597.36
# Random Forest Regressor RMSE Error Percentage: 11.30 %
# Random Forest Regressor Training Time: 42.63 seconds
# Random Forest Regressor Prediction Time: 3.96 seconds
#
# 2) Light GBM Regressor Model
# Light GBM Regressor RMSE: 1356.62
# Light GBM Regressor RMSE Error Percentage: 25.67 %
# Light GBM Regressor Model Training Time: 1.28 seconds
# Light GBM Regressor Prediction Time: 0.77 seconds
#
# 3) CatBoost Regressor Model
# CatBoost Regressor Model RMSE 1491.58
# CatBoost Regressor RMSE Error Percentage: 28.23 %
# CatBoost Regressor Training Time: 3.85 Seconds
# CatBoost Regressor Prediction Time: 0.10
#
# 4) XG Boost Regressor Model
# XG Boost Regressor RMSE: 1495.96
# XG Boost Regressor RMSE Error Percentage: 28.31 %
# XG Boost Regressor Training Time 5.34 seconds
# XG Boost Regressor Prediction Time: 0.67 seconds
#
# 5) Decision Tree Regressor Model
# Decision Tree Regressor RMSE: 2163.39
# Decision Tree Regressor Error Percentage: 40.94 %
# Decision Tree Regressor Training Time 0.52 seconds
# Decision Tree Regressor Prediction Time: 1743725092.55 seconds
#
# 6) Linear Regression Model
# Linear Regression Model RMSE 2128.26
# Linear Regressor RMSE Error Percentage: 40.27 %
# Linear Regression Model Training Time 3.54 seconds
# Linear Regression Model Prediction Time 1743724895.59 seconds
#
# 7) SGD Linear Regression Model
# SGD Linear Regression RMSE: 2226.73
# SGD Linear Regression RMSE Error Percentage: 42.14 %
# SGD Linear Regression Training Time 23.10 seconds
# SGD Prediction Time 0.11 seconds
#
# Results Observation:
# Accoriding to the results, it appears that the Random Forest Regressor Model with tuned hyperparameters had a better RMSE
# score than the other models.  Also, all the models had a better RMSE score than the baseline rmse of a dummy model. I will be
# using the Random Forest Regressor Model in order to make the final prediction on the test set.

# %% [markdown]
# <div class="alert alert-warning" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <h2>   Reviewer's comment 3 </h2>
#
# What else can be improved: I recommend that you don't copy and paste values. If you change anything in the models or dataframe, you will need to change all these values as well.
#
# </div>

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <h2>   Reviewer's comment 2 </h2>
#
# Nice results!
#
# </div>
# <div class="alert alert-warning" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <h2>   Reviewer's comment 2 </h2>
#
#
# - However, I'll still need to run the code to make sure everything is correct. So far I cannot do it because of an issue above.
#
#
#
# - Do you need so many digits after the floating point? :)</div>

# %% [markdown]
# ##### Random Forest Regressor Model Test Set Prediction

# %%
#Use the np.mean() method in order to get the mean for the test set of the target dataset.
y_mean_pred_test = np.mean(y_test)
#Use the rmse() function to calculate the rmse of between the test set of the target dataset and 
#the product of the mean for the test set of the target dataset and the length the of the
#test set of target datset. This will be the baseline rmse for the dataset.
baseline_rmse_test = rmse(y_test, [y_mean_pred_test] * len(y_test)) 
print(f"Baseline RMSE (Test Set): {baseline_rmse_test}") 
#Print Basline RMSE error percentage.
print(f"Baseline RMSE Error Perecentage (Test Set): {rmse_percentage(baseline_rmse_test, price_mean):.2f} %")
# Out:
# Baseline RMSE (Test Set): 4399.836485349227
# Baseline RMSE Error Perecentage (Test Set): 83.26 %

# %%
#Use the time.time() function in order to calculate the start time for the model's
#prediction process.  
rfr_test_st = time.time()

#Use the predict() method in order to make a prediciton based on the test set of the scaled
#features dataset using the  model. 
rfr_test_predicted = rfr.predict(X_test) 

#Use the time.time() function in order to calculate the end time for the model's
#prediction process. 
rfr_test_et = time.time() 

#Calculate the model's total prediction time by subtracting the end time from the start time. 
rfr_predicted_test_time = rfr_test_et - rfr_test_st 
#Print the model's total prediction time. 
print(f"Random Forest Regressor Prediction Time (Test Set): {rfr_predicted_test_time} seconds")

#Use the rmse() method in order to print the rmse between the test set of the target dataset
#and the model's predicted values. 
rfr_test_rmse = rmse(y_test, rfr_test_predicted) 

#Print the model's RMSE. 
print(f"Random Forest Regressor RMSE (Test Set): {rfr_test_rmse}")
#Print the model's RMSE error percentage.
print(f"Random Forest Regressor RMSE Percentage Test Set \n {rmse_percentage(rfr_test_rmse, price_mean):.2f} %")
# Out:
# Random Forest Regressor Prediction Time (Test Set): 5.537988185882568 seconds
# Random Forest Regressor RMSE (Test Set): 1527.7415234787072
# Random Forest Regressor RMSE Percentage Test Set
#  28.91 %

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <h2>   Reviewer's comment 3 </h2>
#
# Well done!
# </div>

# %% [markdown]
# <div class="alert alert-danger" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b>   Reviewer's comment </b>
#
# Now, let's choose the best model based on their training RMSE and run the final test here. Choose the best model and make predictions using the test subset. Calculate RMSE and make a conclusion.
#
# </div>

# %% [markdown]
# #### Final Conclusion:
#     It appears that the Random Forest Regressor model with tuned hyperparameters is the best model for predicting
# future car market values.  When making predicitons on the training set, the Random Forest Regressor Model had an
# RMSE score of: 601.512998833745 and an RMSE error Percentage of: 11.63%.  When making predictions of the test set,
# the Random Forest Regressor Model had an RMSE score of: 1545.8632079286108 and an RMSE  error percentage 28.89 %.
#     Although, the Random Forest Regressor model had the best RMSE score of all the models, its training and prediciton
# time was slower than the other models.  When making predicitons on the training set, the Random Forest Regressor model
# had a training time of: 42.50601601600647 seconds and a prediction time of: 4.156696081161499 seconds.  When making
# predictions the test set, the Random Forest Regressor Model had a prediction time of: 8.707719326019287 seconds.
#
#
# Models Ranked From Highest RMSE Score To Lowest RMSE Score (Training Set Predictions):
# 1) Random Forest Regressor Model
# Random Forest Regressor RMSE: 597.36
# Random Forest Regressor RMSE Error Percentage: 11.30 %
#
# 2) Light GBM Regressor Model
# Light GBM Regressor RMSE: 1356.62
# Light GBM Regressor RMSE Error Percentage: 25.67 %
#
# 3) CatBoost Regressor Model
# CatBoost Regressor Model RMSE 1491.58
# CatBoost Regressor RMSE Error Percentage: 28.23 %
#
# 4) XG Boost Regressor Model
# XG Boost Regressor RMSE: 1495.96
# XG Boost Regressor RMSE Error Percentage: 28.31 %
#
# 5) Decision Tree Regressor Model
# Decision Tree Regressor RMSE: 2163.39
# Decision Tree Regressor Error Percentage: 40.94 %
#
# 6) Linear Regression Model
# Linear Regression Model RMSE 2128.26
# Linear Regressor RMSE Error Percentage: 40.27 %
#
# 7) SGD Linear Regression Model
# SGD Linear Regression RMSE: 2226.73
# SGD Linear Regression RMSE Error Percentage: 42.14 %
#
# Other Observations:
# * When making predictions, the Random Forest Regressor model did better on the training set than on the test set.
# * The regular Linear Regression model had a better RMSE score than the SGD Linear Regression model.
# * The best model is a tree based algorithm and not a boosting or gradient descent algorithm.

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <h2>   Reviewer's comment 3 </h2>
#
# Great job, Byron!
# </div>

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <h2> Reviewer's comment</h2>
#
#
# The conclusion is written well.
# </div>
# <div class="alert alert-warning" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Reviewer's comment</b>
#
#
# You can make it a little broader though.
#
# </div>
# <div class="alert alert-danger" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Reviewer's comment</b>
#
# Don't forget to update it.
#
# </div>

# %% [markdown]
# # Checklist

# %% [markdown]
# Type 'x' to check. Then press Shift+Enter.

# %% [markdown]
# - [x]  Jupyter Notebook is open
# - [ ]  Code is error free
# - [ ]  The cells with the code have been arranged in order of execution
# - [ ]  The data has been downloaded and prepared
# - [ ]  The models have been trained
# - [ ]  The analysis of speed and quality of the models has been performed
